# %%
import pandas as pd
import numpy as np

# %%
df_subvencions = pd.read_csv('../data/Subvencions_atorgades_AjuntBCN_i_Instituts.csv')

# %%
df_subvencions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61696 entries, 0 to 61695
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Entitat_Municipal        61696 non-null  object
#  1   Organ_Gestor             54915 non-null  object
#  2   Beneficiari              61696 non-null  object
#  3   NIF_CIF                  61696 non-null  object
#  4   Tipologia_De_Subvencio   61132 non-null  object
#  5   Codi_De_Subvencio        61696 non-null  object
#  6   Objecte                  61696 non-null  object
#  7   Data_Convocatoria        61696 non-null  object
#  8   Data_Atorgament          61696 non-null  object
#  9   Import_Sollicitat        61696 non-null  float64
#  10  Import_Total_Projecte    61696 non-null  float64
#  11  Import_Atorgat_Inicial   61696 non-null  float64
#  12  Import_Reintegrat_Total  61696 non-null  float64
# dtypes: float64(4), object(9)
# memory usage: 6.1+ MB

# %%
print(df_subvencions.shape)
df_subvencions.head(2)
# Out:
# (61696, 13)
#          Entitat_Municipal                                       Organ_Gestor  \
# 0  Ajuntament de Barcelona  Gerència Drets de Ciutadania, Participació i T...
# 1  Ajuntament de Barcelona                          Gerència de Drets Socials
#
#                          Beneficiari    NIF_CIF  \
# 0       ASSOCIACIO UCRAINESA DJERELO  G65874968
# 1   PROJECTE DELS NOMS - HISPANOSIDA  G60396280
#
#                               Tipologia_De_Subvencio Codi_De_Subvencio  \
# 0  CONVOCATÒRIA GENERAL DE SUBVENCIONS 2019.DRETS...          19S00465
# 1  CONVOCATÒRIA GENERAL DE SUBVENCIONS 2019. GERÈ...          19S00469
#
#                                  Objecte Data_Convocatoria Data_Atorgament  \
# 0                         V Ucrania Fest        24.01.2019      16.09.2019
# 1  26è Memorial Internacional de la Sida        24.01.2019      12.09.2019
#
#    Import_Sollicitat  Import_Total_Projecte  Import_Atorgat_Inicial  \
# 0             5000.0                14900.0                  4500.0
# 1             4000.0                13000.0                  3000.0
#
#    Import_Reintegrat_Total
# 0                      0.0
# 1                      0.0

# %%
df_subvencions.describe().T
# Out:
#                            count           mean           std        min  \
# Import_Sollicitat        61696.0   32622.580025  1.188566e+06        0.0
# Import_Total_Projecte    61696.0   37172.735972  6.939191e+05        0.0
# Import_Atorgat_Inicial   61696.0  117470.655703  2.112606e+06 -4700000.0
# Import_Reintegrat_Total  61696.0     106.704832  5.104336e+03        0.0
#
#                             25%       50%      75%           max
# Import_Sollicitat        1000.0  3200.000   9000.0  1.620830e+08
# Import_Total_Projecte    1500.0  6412.705  20000.0  1.506817e+08
# Import_Atorgat_Inicial   1000.0  2250.000   6000.0  1.607830e+08
# Import_Reintegrat_Total     0.0     0.000      0.0  1.185303e+06

# %%
df_subvencions.describe(include=object).T
# Out:
#                         count unique  \
# Entitat_Municipal       61696     12
# Organ_Gestor            54915     48
# Beneficiari             61696  25247
# NIF_CIF                 61696  18885
# Tipologia_De_Subvencio  61132    260
# Codi_De_Subvencio       61696  49175
# Objecte                 61696  34016
# Data_Convocatoria       61696    112
# Data_Atorgament         61696   1339
#
#                                                                       top  \
# Entitat_Municipal                                 Ajuntament de Barcelona
# Organ_Gestor            Gerència d’Àrea d’Economia, Recursos i Promoci...
# Beneficiari                                    INST. MPAL. CULTURA (ICUB)
# NIF_CIF                                                         P5890006I
# Tipologia_De_Subvencio  AJUT EQUIVALENT A LA QUOTA LÍQUIDA DE L'IBI A ...
# Codi_De_Subvencio                                                23S00061
# Objecte                                                POCS RECURSOS 2019
# Data_Convocatoria                                              00.00.0000
# Data_Atorgament                                                17.12.2019
#
#                          freq
# Entitat_Municipal       46213
# Organ_Gestor             9349
# Beneficiari               220
# NIF_CIF                   225
# Tipologia_De_Subvencio   5795
# Codi_De_Subvencio           7
# Objecte                  5795
# Data_Convocatoria       27889
# Data_Atorgament          5821

# %%
df_subvencions[df_subvencions.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Entitat_Municipal, Organ_Gestor, Beneficiari, NIF_CIF, Tipologia_De_Subvencio, Codi_De_Subvencio, Objecte, Data_Convocatoria, Data_Atorgament, Import_Sollicitat, Import_Total_Projecte, Import_Atorgat_Inicial, Import_Reintegrat_Total]
# Index: []

# %%
df_subvencions.isnull().sum()
# Out:
# Entitat_Municipal             0
# Organ_Gestor               6781
# Beneficiari                   0
# NIF_CIF                       0
# Tipologia_De_Subvencio      564
# Codi_De_Subvencio             0
# Objecte                       0
# Data_Convocatoria             0
# Data_Atorgament               0
# Import_Sollicitat             0
# Import_Total_Projecte         0
# Import_Atorgat_Inicial        0
# Import_Reintegrat_Total       0
# dtype: int64

# %%
df_subvencions['Organ_Gestor'].value_counts()
# Out:
# Organ_Gestor
# Gerència d’Àrea d’Economia, Recursos i Promoció Econòmica                9349
# Gerència de Presidència i Economia                                       6072
# Institut de Cultura de Barcelona                                         5282
# Gerència Àrea D.Socials,Salut,Cooperac. i Comunit.                       3397
# Gerència Drets de Ciutadania, Participació i Transparència               3239
# Gerència Àrea Cultura,Educació,Esports i Cicles V.                       2213
# Gerència d'Area de Drets Socials, Justícia Global, Feminismes i LGTBI    1842
# Districte de Ciutat Vella                                                1602
# Districte d'Horta-Guinardó                                               1559
# Districte de Sant Martí                                                  1477
# Districte de Sants-Montjuic                                              1377
# Districte de Sant Andreu                                                 1328
# Districte de Nou Barris                                                  1300
# Districte de l'Eixample                                                  1288
# Institut Barcelona Esports                                               1201
# Districte de Gràcia                                                      1131
# Institut Municipal de Persones amb Discapacitat                          1060
# Gerència d’Àrea de Cultura, Educació, Ciència i Comunitat                 970
# Districte de Sarrià-St.Gervasi                                            887
# Gerència de Drets Socials                                                 871
# Gerència d'Area d'Ecologia Urbana                                         851
# Gerència de Política Econòmica i Desenvolupament                          783
# Promoció econòmica                                                        747
# Gerència Adjunta de Mediambient i Serveis Urbans                          676
# Districte de les Corts                                                    654
# Institut Municipal de serveis Socials                                     616
# Gerència Ecologia Urbana                                                  504
# Gerència de Turisme, Comerç i Mercats                                     406
# Institut Municipal del Paisatge Urbà i la Qualitat de Vida                386
# Ger.d'Àrea de Mobilitat, Infraestruc. i Svs Urbans                        298
# Institut Municipal d' Hisenda                                             236
# Gerència de Recursos                                                      230
# Gerència de Pressupostos i Hisenda                                        216
# Gerència Municipal                                                        172
# Gerència d'Àrea d'Agenda 2030, Transició Digital i Esports                148
# Institut Municipal d'Educació de Barcelona                                136
# Gerència d'Àrea d'Agenda 2030, Transició Digital,                         106
# Gerència de Serveis Generals                                               96
# Gerència d'Empresa, Cultura i Innovació                                    40
# Gerència d'Àrea Seguretat i Prevenció                                      38
# Gerència adjunta d'Infraestructures i Coordinació Urbana                   32
# Gerència de Persones i Desenvolupament Organitzatiu                        25
# Gerència adjunta d'Urbanisme                                               16
# Gerènc. Svs Urbans i Manteniment de l’Espai Públic                         15
# Gerencia de RRHH i Organització                                            14
# Gerencia Municipal                                                         13
# Gerència de l'Habitatge                                                    11
# Gerència d'Àrea de Seguretat i Prevenció                                    5
# Name: count, dtype: int64

# %%
df_subvencions[df_subvencions['Organ_Gestor'].isnull()]
# Out:
#                           Entitat_Municipal Organ_Gestor  \
# 640           Institut Municipal d'Educació          NaN
# 641           Institut Municipal d'Educació          NaN
# 642           Institut Municipal d'Educació          NaN
# 643           Institut Municipal d'Educació          NaN
# 644           Institut Municipal d'Educació          NaN
# ...                                     ...          ...
# 61691  Institut Municipal Barcelona Esports          NaN
# 61692  Institut Municipal Barcelona Esports          NaN
# 61693  Institut Municipal Barcelona Esports          NaN
# 61694  Institut Municipal Barcelona Esports          NaN
# 61695  Institut Municipal Barcelona Esports          NaN
#
#                              Beneficiari    NIF_CIF  \
# 640              NATALIA ANGLES I BERNAL  48023217E
# 641                   BERTA ARIAS RUESGA  49292612R
# 642               DEIDRE ATIENZAR CEBRIA  26068801A
# 643             ARIADNA BIETO I ESTRELLA  23922664L
# 644                     CABRERA CORONADO  26910572C
# ...                                  ...        ...
# 61691            CLUB NATACION BARCELONA  G08533689
# 61692  REAL CLUB DE TENIS BARCELONA-1899  G08555278
# 61693             Unió Esportiva d'Horta  G08675738
# 61694   Fed Esp Cat Paralítics Cerebrals  G60121043
# 61695   Fed Esp Cat Paralítics Cerebrals  G60121043
#
#                            Tipologia_De_Subvencio Codi_De_Subvencio  \
# 640    SUBVENCIONS DIRECTES (amb o sense CONVENI)          20S00158
# 641    SUBVENCIONS DIRECTES (amb o sense CONVENI)          20S00159
# 642    SUBVENCIONS DIRECTES (amb o sense CONVENI)          20S00160
# 643    SUBVENCIONS DIRECTES (amb o sense CONVENI)          20S00161
# 644    SUBVENCIONS DIRECTES (amb o sense CONVENI)          20S00162
# ...                                           ...               ...
# 61691  SUBVENCIONS DIRECTES (amb o sense CONVENI)          20S00988
# 61692  SUBVENCIONS DIRECTES (amb o sense CONVENI)          20S00989
# 61693  SUBVENCIONS DIRECTES (amb o sense CONVENI)          20S00991
# 61694  SUBVENCIONS DIRECTES (amb o sense CONVENI)          21S00311
# 61695  SUBVENCIONS DIRECTES (amb o sense CONVENI)          21S00313
#
#                                               Objecte Data_Convocatoria  \
# 640    BECA FP DUAL NATALIA ANGLES I BERNAL 2020-2021        00.00.0000
# 641         BECA FP DUAL BERTA ARIAS RUESGA 2020-2021        00.00.0000
# 642     BECA FP DUAL DEIDRE ATIENZAR CEBRIA 2020-2021        00.00.0000
# 643     BECA FP DUAL ARIADNA BIETO ESTRELLA 2020-2021        00.00.0000
# 644    BECA FP DUAL SHEYLA CABRERA CORONADO 2020-2021        00.00.0000
# ...                                               ...               ...
# 61691   Convocatòria subv entitats esportives - COVID        00.00.0000
# 61692   Convocatòria subv entitats esportives - COVID        00.00.0000
# 61693   Convocatòria subv entitats esportives - COVID        00.00.0000
# 61694               Conveni DIBA 2020 - Esdeveniments        00.00.0000
# 61695               Conveni DIBA 2020 - Esdeveniments        00.00.0000
#
#       Data_Atorgament  Import_Sollicitat  Import_Total_Projecte  \
# 640        20.11.2020            2521.13                2521.13
# 641        20.11.2020            2521.13                2521.13
# 642        20.11.2020            2521.13                2521.13
# 643        20.11.2020            2521.13                2521.13
# 644        20.11.2020            2521.13                2521.13
# ...               ...                ...                    ...
# 61691      31.12.2020           25000.00               25000.00
# 61692      31.12.2020           25000.00               25000.00
# 61693      31.12.2020           18993.41               18993.41
# 61694      06.05.2021            5000.00                5000.00
# 61695      29.04.2021            8000.00                8000.00
#
#        Import_Atorgat_Inicial  Import_Reintegrat_Total
# 640                   2521.13                      0.0
# 641                   2499.44                      0.0
# 642                   1161.02                      0.0
# 643                   1286.21                      0.0
# 644                   2480.79                      0.0
# ...                       ...                      ...
# 61691                25000.00                      0.0
# 61692                25000.00                      0.0
# 61693                18993.41                      0.0
# 61694                 5000.00                      0.0
# 61695                 8000.00                      0.0
#
# [6781 rows x 13 columns]

# %%
df_subvencions['Organ_Gestor'].fillna('no_gestor', inplace=True)
# Out:
# C:\Users\harol\AppData\Local\Temp\ipykernel_15960\3572163831.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_subvencions['Organ_Gestor'].fillna('no_gestor', inplace=True)

# %%
df_subvencions['Organ_Gestor'].value_counts(normalize=True)*100
# Out:
# Organ_Gestor
# Gerència d’Àrea d’Economia, Recursos i Promoció Econòmica                15.153332
# no_gestor                                                                10.990988
# Gerència de Presidència i Economia                                        9.841805
# Institut de Cultura de Barcelona                                          8.561333
# Gerència Àrea D.Socials,Salut,Cooperac. i Comunit.                        5.506030
# Gerència Drets de Ciutadania, Participació i Transparència                5.249935
# Gerència Àrea Cultura,Educació,Esports i Cicles V.                        3.586942
# Gerència d'Area de Drets Socials, Justícia Global, Feminismes i LGTBI     2.985607
# Districte de Ciutat Vella                                                 2.596603
# Districte d'Horta-Guinardó                                                2.526906
# Districte de Sant Martí                                                   2.393996
# Districte de Sants-Montjuic                                               2.231911
# Districte de Sant Andreu                                                  2.152490
# Districte de Nou Barris                                                   2.107106
# Districte de l'Eixample                                                   2.087656
# Institut Barcelona Esports                                                1.946642
# Districte de Gràcia                                                       1.833182
# Institut Municipal de Persones amb Discapacitat                           1.718102
# Gerència d’Àrea de Cultura, Educació, Ciència i Comunitat                 1.572225
# Districte de Sarrià-St.Gervasi                                            1.437695
# Gerència de Drets Socials                                                 1.411761
# Gerència d'Area d'Ecologia Urbana                                         1.379344
# Gerència de Política Econòmica i Desenvolupament                          1.269126
# Promoció econòmica                                                        1.210775
# Gerència Adjunta de Mediambient i Serveis Urbans                          1.095695
# Districte de les Corts                                                    1.060036
# Institut Municipal de serveis Socials                                     0.998444
# Gerència Ecologia Urbana                                                  0.816909
# Gerència de Turisme, Comerç i Mercats                                     0.658065
# Institut Municipal del Paisatge Urbà i la Qualitat de Vida                0.625648
# Ger.d'Àrea de Mobilitat, Infraestruc. i Svs Urbans                        0.483013
# Institut Municipal d' Hisenda                                             0.382521
# Gerència de Recursos                                                      0.372796
# Gerència de Pressupostos i Hisenda                                        0.350104
# Gerència Municipal                                                        0.278786
# Gerència d'Àrea d'Agenda 2030, Transició Digital i Esports                0.239886
# Institut Municipal d'Educació de Barcelona                                0.220436
# Gerència d'Àrea d'Agenda 2030, Transició Digital,                         0.171810
# Gerència de Serveis Generals                                              0.155602
# Gerència d'Empresa, Cultura i Innovació                                   0.064834
# Gerència d'Àrea Seguretat i Prevenció                                     0.061592
# Gerència adjunta d'Infraestructures i Coordinació Urbana                  0.051867
# Gerència de Persones i Desenvolupament Organitzatiu                       0.040521
# Gerència adjunta d'Urbanisme                                              0.025934
# Gerènc. Svs Urbans i Manteniment de l’Espai Públic                        0.024313
# Gerencia de RRHH i Organització                                           0.022692
# Gerencia Municipal                                                        0.021071
# Gerència de l'Habitatge                                                   0.017829
# Gerència d'Àrea de Seguretat i Prevenció                                  0.008104
# Name: proportion, dtype: float64

# %%
df_subvencions['Tipologia_De_Subvencio'].value_counts()
# Out:
# Tipologia_De_Subvencio
# AJUT EQUIVALENT A LA QUOTA LÍQUIDA DE L'IBI A PERSONES AMB POCS     5795
# AJUTS                                                               5481
# SUBVENCIONS DIRECTES (amb o sense CONVENI)                          5071
# PROJ. INVERS. ESTABLIMENTS ECON. LOCAL CONCURRÈNCIA NO COMPETITI    2752
# TRANSFERÈNCIES ENS PÚBLICS I ALTRES                                 2603
#                                                                     ...
# CONVOCATÒRIA DRETS SOCIALS I LABORALS DE LES TREBALLADORES SEXUA       1
# PROJECTE PILOT AMUNT!                                                  1
# Convocatòria planificació, gestió i seguiments PDC 2018                1
# CONVOCATÒRIA GENERAL DE SUBVENCIONS 2018. SARRIA- SANT GERVASI         1
# CONVOCATÒRIA XIV edició del Premi 25 de Novembre                       1
# Name: count, Length: 260, dtype: int64

# %%
df_subvencions[df_subvencions['Tipologia_De_Subvencio'].isnull()]
# Out:
#              Entitat_Municipal  \
# 18782  Ajuntament de Barcelona
# 18815  Ajuntament de Barcelona
# 18845  Ajuntament de Barcelona
# 18846  Ajuntament de Barcelona
# 18882  Ajuntament de Barcelona
# ...                        ...
# 59845  Ajuntament de Barcelona
# 60744  Ajuntament de Barcelona
# 60788  Ajuntament de Barcelona
# 60789  Ajuntament de Barcelona
# 60861  Ajuntament de Barcelona
#
#                                             Organ_Gestor  \
# 18782                          Districte de Ciutat Vella
# 18815  Gerència d’Àrea de Cultura, Educació, Ciència ...
# 18845  Gerència d’Àrea d’Economia, Recursos i Promoci...
# 18846  Gerència d'Area de Drets Socials, Justícia Glo...
# 18882  Gerència d'Area de Drets Socials, Justícia Glo...
# ...                                                  ...
# 59845                                Districte de Gràcia
# 60744  Gerència d’Àrea d’Economia, Recursos i Promoci...
# 60788  Gerència d'Area de Drets Socials, Justícia Glo...
# 60789  Gerència d'Area de Drets Socials, Justícia Glo...
# 60861  Gerència d'Area de Drets Socials, Justícia Glo...
#
#                               Beneficiari    NIF_CIF Tipologia_De_Subvencio  \
# 18782    ASS CULTURAL I SOCIAL L'EM I JPC  G64031958                    NaN
# 18815   ASOC EXPANSION DE LA XARXA OBERTA  G65319832                    NaN
# 18845  ASSOCIACIÓ CAMBRA LGTBIQ CATALUNYA  G64717812                    NaN
# 18846          ASSOCIACIO SETEM CATALUNYA  G59523910                    NaN
# 18882                   ASSOC. CA LA DONA  G58505280                    NaN
# ...                                   ...        ...                    ...
# 59845                    CERCLE DE GRÀCIA  G08534984                    NaN
# 60744                    FUNDACIÓN SHIP2B  G66220286                    NaN
# 60788           PALLASSOS SENSE FRONTERES  G60343951                    NaN
# 60789              FUNDACIO BARCELONACTUA  G66571746                    NaN
# 60861             GRAIN FUNDACION PRIVADA  G59361873                    NaN
#
#       Codi_De_Subvencio                                            Objecte  \
# 18782          21S04964        Conveni col·laboració Projecte Ens Raval'EM
# 18815          21S05362      Conveni eXO.cat Xarxa Oberta inclusió digital
# 18845          21S05178        Promoció i dinamització BCN LGTBIQ (ACEGAL)
# 18846          21S05179                                 Conveni Setem 2021
# 18882          21S05210                            Conveni Ca la Dona 2021
# ...                 ...                                                ...
# 59845          21S13098       Promoció Activitats Culturals Cercle Catòlic
# 60744          22S08583                             IX Ship2B Impact Forum
# 60788          22S09646  PSF -Suport a infància refugiada i vulnerable ...
# 60789          22S09648                             Conveni BCN Actua 2022
# 60861          21S09399                         Barcelona menja bé i just!
#
#       Data_Convocatoria Data_Atorgament  Import_Sollicitat  \
# 18782        00.00.0000      21.10.2021            49630.0
# 18815        00.00.0000      28.06.2021            15075.4
# 18845        00.00.0000      09.09.2021            66905.0
# 18846        00.00.0000      08.07.2021            65000.0
# 18882        00.00.0000      01.07.2021            31050.0
# ...                 ...             ...                ...
# 59845        00.00.0000      27.12.2021            13000.0
# 60744        00.00.0000      29.09.2022            50000.0
# 60788        00.00.0000      27.12.2022            29900.0
# 60789        00.00.0000      22.12.2022           150000.0
# 60861        00.00.0000      21.10.2021            80000.0
#
#        Import_Total_Projecte  Import_Atorgat_Inicial  Import_Reintegrat_Total
# 18782                50000.0                 49630.0                      0.0
# 18815                15075.4                 15075.4                      0.0
# 18845               245735.0                116905.0                      0.0
# 18846               130000.0                 65000.0                      0.0
# 18882                34500.0                 31050.0                      0.0
# ...                      ...                     ...                      ...
# 59845                    0.0                 13000.0                      0.0
# 60744               404722.9                 50000.0                      0.0
# 60788                55645.0                 29900.0                      0.0
# 60789               187500.0                150000.0                      0.0
# 60861               160000.0                 80000.0                      0.0
#
# [564 rows x 13 columns]

# %%
df_subvencions['Tipologia_De_Subvencio'].fillna('no_tipo', inplace=True)
# Out:
# C:\Users\harol\AppData\Local\Temp\ipykernel_15960\4190768758.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_subvencions['Tipologia_De_Subvencio'].fillna('no_tipo', inplace=True)

# %%
df_subvencions['Tipologia_De_Subvencio'].value_counts(normalize=True)
# Out:
# Tipologia_De_Subvencio
# AJUT EQUIVALENT A LA QUOTA LÍQUIDA DE L'IBI A PERSONES AMB POCS     0.093928
# AJUTS                                                               0.088839
# SUBVENCIONS DIRECTES (amb o sense CONVENI)                          0.082193
# PROJ. INVERS. ESTABLIMENTS ECON. LOCAL CONCURRÈNCIA NO COMPETITI    0.044606
# TRANSFERÈNCIES ENS PÚBLICS I ALTRES                                 0.042191
#                                                                       ...
# CONVOCATÒRIA DRETS SOCIALS I LABORALS DE LES TREBALLADORES SEXUA    0.000016
# PROJECTE PILOT AMUNT!                                               0.000016
# CONVOCATÒRIA GENERAL DE SUBVENCIONS 2018. SARRIA- SANT GERVASI      0.000016
# Convocatòria planificació, gestió i seguiments PDC 2018             0.000016
# CONVOCATÒRIA XIV edició del Premi 25 de Novembre                    0.000016
# Name: proportion, Length: 261, dtype: float64

# %%
df_subvencions['Entitat_Municipal'].value_counts()
# Out:
# Entitat_Municipal
# Ajuntament de Barcelona                                       46213
# Institut de Cultura de Barcelona                               6476
# Institut Municipal Barcelona Esports                           3599
# Institut Barcelona Esports                                     1201
# Institut Municipal de persones amb Discapacitat                1060
# Institut Municipal de Serveis Socials                           984
# Institut Municipal d'Educació                                   603
# Institut Municipal de Persones amb Discapacitat                 510
# Institut Municipal del Paisatge Urbà i la Qualitat de Vida      386
# Institut Municipal de Mercats de Barcelona                      292
# Institut Municipal d' Hisenda                                   236
# Institut Municipal d'Educació de Barcelona                      136
# Name: count, dtype: int64
